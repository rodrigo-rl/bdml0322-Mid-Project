# %% [markdown]
# ## MID CAMP PROJECT - EUROCUP 2020
#
# El proyecto de mitad de bootcamp va a consistir en mostrar en streamlit una serie de datos ordenados en tablas, de forma que el usuario pueda interactuar con ellos.
#
# El tema que se va a utilizar en este caso es la EUROCUP 2020 (que por la pandemia del COVID-19 se retrasó al año siguiente).
#
# Lo primero que se va a realizar es obtener esos datos de la base de datos de kaggle (https://www.kaggle.com/mcarujo/euro-cup-2020). Esos datos se van a tratar antes de subirlos a la página  de bases de datos MongoDB.
#
# Esos datos son los que una API programada al efecto va a interpretar para mostrarlos en el entorno de streamlit.

# %%
import re
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv("../data/eurocup_2020_results.csv")

# %%
df
# Out:
#                         stage          date   pens pens_home_score  \
# 0                      Final     11.07.2021   True               3
# 1                Semi-finals    07.07.2021   False           False
# 2                Semi-finals     06.07.2021   True               4
# 3             Quarter-finals    03.07.2021   False           False
# 4             Quarter-finals    03.07.2021   False           False
# 5             Quarter-finals    02.07.2021   False           False
# 6             Quarter-finals     02.07.2021   True               1
# 7                Round of 16    29.06.2021   False           False
# 8                Round of 16    29.06.2021   False           False
# 9                Round of 16     28.06.2021   True               4
# 10               Round of 16    28.06.2021   False           False
# 11               Round of 16    27.06.2021   False           False
# 12               Round of 16    27.06.2021   False           False
# ...

# %%
print(df['events_list'][0])
# Out:
# [{'event_team': 'away', 'event_time': " 2' ", 'event_type': 'Goal', 'action_player_1': ' Luke Shaw ', 'action_player_2': ' Kieran Trippier '}, {'event_team': 'home', 'event_time': " 47' ", 'event_type': 'Yellow card', 'action_player_1': ' Nicolo Barella '}, {'event_team': 'home', 'event_time': " 54' ", 'event_type': 'Substitution', 'action_player_1': ' Bryan Cristante ', 'action_player_2': ' Nicolo Barella '}, {'event_team': 'home', 'event_time': " 55' ", 'event_type': 'Yellow card', 'action_player_1': ' Leonardo Bonucci '}, {'event_team': 'home', 'event_time': " 55' ", 'event_type': 'Substitution', 'action_player_1': ' Domenico Berardi ', 'action_player_2': ' Ciro Immobile '}, {'event_team': 'home', 'event_time': " 67' ", 'event_type': 'Goal', 'action_player_1': ' Leonardo Bonucci '}, {'event_team': 'away', 'event_time': " 70' ", 'event_type': 'Substitution', 'action_player_1': ' Bukayo Saka ', 'action_player_2': ' Kieran Trippier '}, {'event_team': 'away', 'event_time': " 74' ", 'e
# ...

# %%
ast.literal_eval(df['events_list'][0])
# Out:
# [{'event_team': 'away',
#   'event_time': " 2' ",
#   'event_type': 'Goal',
#   'action_player_1': ' Luke Shaw ',
#   'action_player_2': ' Kieran Trippier '},
#  {'event_team': 'home',
#   'event_time': " 47' ",
#   'event_type': 'Yellow card',
#   'action_player_1': ' Nicolo Barella '},
#  {'event_team': 'home',
#   'event_time': " 54' ",
#   'event_type': 'Substitution',
#   'action_player_1': ' Bryan Cristante ',
#   'action_player_2': ' Nicolo Barella '},
#  {'event_team': 'home',
#   'event_time': " 55' ",
#   'event_type': 'Yellow card',
#   'action_player_1': ' Leonardo Bonucci '},
#  {'event_team': 'home',
#   'event_time': " 55' ",
#   'event_type': 'Substitution',
#   'action_player_1': ' Domenico Berardi ',
#   'action_player_2': ' Ciro Immobile '},
#  {'event_team': 'home',
#   'event_time': " 67' ",
#   'event_type': 'Goal',
#   'action_player_1': ' Leonardo Bonucci '},
#  {'event_team': 'away',
#   'event_time': " 70' ",
#   'event_type': 'Substitution',
# ...

# %%
df_repaired=df

# %%
for row in range(len(df_repaired)):
    for column in df_repaired:

        if isinstance(df_repaired[column].iloc[row],str):
            df_repaired[column].iloc[row]=df_repaired[column].iloc[row].lstrip().rstrip()
            if column == 'events_list' or column == 'lineup_home' or column == 'lineup_away':
                df_repaired[column].iloc[row]=ast.literal_eval(df_repaired[column].iloc[row])
                print(type(df_repaired[column].iloc[row]), column, row)
   
        elif isinstance(df[column][0], np.bool_):
            df_repaired[column].iloc[row]=bool(df_repaired[column].iloc[row])

        elif isinstance(df[column][0], np.int64):
            df_repaired[column].iloc[row]=df_repaired[column].iloc[row].item()
        
print(row, column)
# Out:
# /tmp/ipykernel_1190/167460589.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_repaired[column].iloc[row]=df_repaired[column].iloc[row].lstrip().rstrip()
# /tmp/ipykernel_1190/167460589.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_repaired[column].iloc[row]=bool(df_repaired[column].iloc[row])
# /tmp/ipykernel_1190/167460589.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_repaired
# Out:
#                       stage        date   pens pens_home_score  \
# 0                     Final  11.07.2021   True               3
# 1               Semi-finals  07.07.2021  False           False
# 2               Semi-finals  06.07.2021   True               4
# 3            Quarter-finals  03.07.2021  False           False
# 4            Quarter-finals  03.07.2021  False           False
# 5            Quarter-finals  02.07.2021  False           False
# 6            Quarter-finals  02.07.2021   True               1
# 7               Round of 16  29.06.2021  False           False
# 8               Round of 16  29.06.2021  False           False
# 9               Round of 16  28.06.2021   True               4
# 10              Round of 16  28.06.2021  False           False
# 11              Round of 16  27.06.2021  False           False
# 12              Round of 16  27.06.2021  False           False
# 13              Round of 16  26.06.2021  False           False
# ...

# %%
for column in df_repaired:
    print(df_repaired[column][4])
    print(type(df_repaired[column][4]))
    print('-----------------')
# Out:
# Quarter-finals
# <class 'str'>
# -----------------
# 03.07.2021
# <class 'str'>
# -----------------
# False
# <class 'numpy.bool_'>
# -----------------
# False
# <class 'str'>
# -----------------
# False
# <class 'str'>
# -----------------
# Czech Republic
# <class 'str'>
# -----------------
# Denmark
# <class 'str'>
# -----------------
# 1
# <class 'numpy.int64'>
# -----------------
# 2
# <class 'numpy.int64'>
# -----------------
# 56%
# <class 'str'>
# -----------------
# 44%
# <class 'str'>
# -----------------
# 16
# <class 'numpy.int64'>
# -----------------
# 11
# <class 'numpy.int64'>
# -----------------
# 5
# <class 'numpy.int64'>
# -----------------
# 7
# <class 'numpy.int64'>
# -----------------
# 48%
# <class 'str'>
# -----------------
# 52%
# <class 'str'>
# -----------------
# ...

# %%
from pymongo import MongoClient

# %%
mongo_url="mongodb+srv://Prueba:Prueba@eurocup-2020.zgna6.mongodb.net/test"

client = MongoClient(mongo_url)
db = client.get_database("EUROCUP-2020")
match_db= db.Matches

# %%
client
# Out:
# MongoClient(host=['eurocup-2020-shard-00-00.zgna6.mongodb.net:27017', 'eurocup-2020-shard-00-01.zgna6.mongodb.net:27017', 'eurocup-2020-shard-00-02.zgna6.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-qlhmy4-shard-0', ssl=True)

# %%
for row in range(len(df_repaired)):
    match={}
    for column in df:
        if df_repaired[column].iloc[row]== True:
            match[column]='True'
        elif df_repaired[column].iloc[row]== False:
            match[column]='False'
        elif isinstance(df_repaired[column].iloc[row], np.int64):
            match[column]=int(df_repaired[column].iloc[row])
 #           print(type(df[column].iloc[row]))
 #           print(df[column].iloc[row])
            
        else:
#            print(type(df[column].iloc[row]))
#            print(df[column].iloc[row])
            
            match[column]=df_repaired[column].iloc[row]
    match_db.insert_one(match)
