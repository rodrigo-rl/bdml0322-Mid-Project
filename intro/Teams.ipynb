# %% [markdown]
# En este código se va a generar los datos para obtener los datos de los partidos por equipo

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient

# %%
mongo_url="mongodb+srv://Prueba:Prueba@eurocup-2020.zgna6.mongodb.net/test"

client = MongoClient(mongo_url)
db = client.get_database("EUROCUP-2020")
match_db= db.Matches

# %%
countries=["England","Italy","Denmark","Spain","Ukraine","Czech Republic","Belgium","Switzerland","Sweden","Germany","France","Croatia","Portugal","Netherlands","Austria","Wales","Hungary","Poland","Slovakia","Scotland","Finland","Russia","North Macedonia","Turkey"]

# %%
results={}
count=0
    
for country in countries:
    results={}
    results['country']=country
    for match in list(match_db.find({})):
    
        if country== match['team_name_home']:
            results[match['stage']]=match['date']
            
            #goles del equipo
            if match['team_home_score']=='True':
                results[f"{match['stage']}_goals"]=1
            elif match['team_home_score']=='False':
                results[f"{match['stage']}_goals"]=0
            else:
                results[f"{match['stage']}_goals"]=match['team_home_score']
            
            #penaltis del equipo
            if match['pens']=='False':
                results[f"{match['stage']}_pens"]=0#match['stage']
            else:
                if match['pens_home_score']=='True':
                    results[f"{match['stage']}_pens"]=1
                else:
                    results[f"{match['stage']}_pens"]=match['pens_home_score']


            #nombre del rival
            results[f"{match['stage']}_rival"]=match['team_name_away']

            #goles del rival
            if match['team_away_score']=='True':
                results[f"{match['stage']}_rival_goals"]=1
            elif match['team_away_score']=='False':
                results[f"{match['stage']}_rival_goals"]=0
            else:
                results[f"{match['stage']}_rival_goals"]=match['team_away_score']

            #penaltis del rival
            if match['pens']=='False':
                results[f"{match['stage']}_rival_pens"]=0#match['stage']
            else:
                if match['pens_away_score']=='True':
                    results[f"{match['stage']}_rival_pens"]=1
                else:
                    results[f"{match['stage']}_rival_pens"]=match['pens_away_score']
            
            

            
        elif country== match['team_name_away']:
            results[match['stage']]=match['date']

            #goles del equipo
            if match['team_away_score']=='True':
                results[f"{match['stage']}_goals"]=1
            elif match['team_away_score']=='False':
                results[f"{match['stage']}_goals"]=0
            else:
                results[f"{match['stage']}_goals"]=match['team_away_score']

            #penaltis del equipo
            if match['pens']=='False':
                results[f"{match['stage']}_pens"]=0
            else:
                if match['pens_away_score']=='True':
                    results[f"{match['stage']}_pens"]=1
                else:
                    results[f"{match['stage']}_pens"]=match['pens_away_score']

            #nombre del rival
            results[f"{match['stage']}_rival"]=match['team_name_home']

            #goles del rival
            if match['team_home_score']=='True':
                results[f"{match['stage']}_rival_goals"]=1
            elif match['team_home_score']=='False':
                results[f"{match['stage']}_rival_goals"]=0
            else:
                results[f"{match['stage']}_rival_goals"]=match['team_home_score']

            #penaltis del rival
            if match['pens']=='False':
                results[f"{match['stage']}_rival_pens"]=0#match['stage']
            else:
                if match['pens_home_score']=='True':
                    results[f"{match['stage']}_rival_pens"]=1
                else:
                    results[f"{match['stage']}_rival_pens"]=match['pens_home_score']

        else:
            pass 
    
    goals_db= db.Teams
    goals_db.insert_one(results)

# %%
results
# Out:
# {'country': 'Turkey',
#  'Group stage: Matchday 3': '20.06.2021',
#  'Group stage: Matchday 3_goals': 1,
#  'Group stage: Matchday 3_pens': 0,
#  'Group stage: Matchday 3_rival': 'Switzerland',
#  'Group stage: Matchday 3_rival_goals': 3,
#  'Group stage: Matchday 3_rival_pens': 0,
#  'Group stage: Matchday 2': '16.06.2021',
#  'Group stage: Matchday 2_goals': 0,
#  'Group stage: Matchday 2_pens': 0,
#  'Group stage: Matchday 2_rival': 'Wales',
#  'Group stage: Matchday 2_rival_goals': 2,
#  'Group stage: Matchday 2_rival_pens': 0,
#  'Group stage: Matchday 1': '11.06.2021',
#  'Group stage: Matchday 1_goals': 0,
#  'Group stage: Matchday 1_pens': 0,
#  'Group stage: Matchday 1_rival': 'Italy',
#  'Group stage: Matchday 1_rival_goals': 3,
#  'Group stage: Matchday 1_rival_pens': 0,
#  '_id': ObjectId('62910def8f73be639b099efc')}

# %%
countries_1=['Belgium']

# %%
results={}
count=0
    
for country in countries_1:
    for match in list(match_db.find({})):
    
        if country== match['team_name_home']:
            results[match['stage']]=match['date']
            
            #goles del equipo
            if match['team_home_score']=='True':
                results[f"{match['stage']}_goals"]=1
            elif match['team_home_score']=='False':
                results[f"{match['stage']}_goals"]=0
            else:
                results[f"{match['stage']}_goals"]=match['team_home_score']
            
            #penaltis del equipo
            if match['pens']=='False':
                results[f"{match['stage']}_pens"]=0#match['stage']
            else:
                if match['pens_home_score']=='True':
                    results[f"{match['stage']}_pens"]=1
                else:
                    results[f"{match['stage']}_pens"]=match['pens_home_score']


            #nombre del rival
            results[f"{match['stage']}_rival"]=match['team_name_away']

            #goles del rival
            if match['team_away_score']=='True':
                results[f"{match['stage']}_rival_goals"]=1
            elif match['team_away_score']=='False':
                results[f"{match['stage']}_rival_goals"]=0
            else:
                results[f"{match['stage']}_rival_goals"]=match['team_away_score']

            #penaltis del rival
            if match['pens']=='False':
                results[f"{match['stage']}_rival_pens"]=0#match['stage']
            else:
                if match['pens_away_score']=='True':
                    results[f"{match['stage']}_rival_pens"]=1
                else:
                    results[f"{match['stage']}_rival_pens"]=match['pens_away_score']
            
            

            
        elif country== match['team_name_away']:
            results[match['stage']]=match['date']

            #goles del equipo
            if match['team_away_score']=='True':
                results[f"{match['stage']}_goals"]=1
            elif match['team_away_score']=='False':
                results[f"{match['stage']}_goals"]=0
            else:
                results[f"{match['stage']}_goals"]=match['team_away_score']

            #penaltis del equipo
            if match['pens']=='False':
                results[f"{match['stage']}_pens"]=0
            else:
                if match['pens_away_score']=='True':
                    results[f"{match['stage']}_pens"]=1
                else:
                    results[f"{match['stage']}_pens"]=match['pens_away_score']

            #nombre del rival
            results[f"{match['stage']}_rival"]=match['team_name_home']

            #goles del rival
            if match['team_home_score']=='True':
                results[f"{match['stage']}_rival_goals"]=1
            elif match['team_home_score']=='False':
                results[f"{match['stage']}_rival_goals"]=0
            else:
                results[f"{match['stage']}_rival_goals"]=match['team_home_score']

            #penaltis del rival
            if match['pens']=='False':
                results[f"{match['stage']}_rival_pens"]=0#match['stage']
            else:
                if match['pens_home_score']=='True':
                    results[f"{match['stage']}_rival_pens"]=1
                else:
                    results[f"{match['stage']}_rival_pens"]=match['pens_home_score']

        else:
            pass

# %%
results
# Out:
# {'Quarter-finals': '02.07.2021',
#  'Quarter-finals_goals': 1,
#  'Quarter-finals_pens': 0,
#  'Quarter-finals_rival': 'Italy',
#  'Quarter-finals_rival_goals': 2,
#  'Quarter-finals_rival_pens': 0,
#  'Round of 16': '27.06.2021',
#  'Round of 16_goals': 1,
#  'Round of 16_pens': 0,
#  'Round of 16_rival': 'Portugal',
#  'Round of 16_rival_goals': 0,
#  'Round of 16_rival_pens': 0,
#  'Group stage: Matchday 3': '21.06.2021',
#  'Group stage: Matchday 3_goals': 2,
#  'Group stage: Matchday 3_pens': 0,
#  'Group stage: Matchday 3_rival': 'Finland',
#  'Group stage: Matchday 3_rival_goals': 0,
#  'Group stage: Matchday 3_rival_pens': 0,
#  'Group stage: Matchday 2': '17.06.2021',
#  'Group stage: Matchday 2_goals': 2,
#  'Group stage: Matchday 2_pens': 0,
#  'Group stage: Matchday 2_rival': 'Denmark',
#  'Group stage: Matchday 2_rival_goals': 1,
#  'Group stage: Matchday 2_rival_pens': 0,
#  'Group stage: Matchday 1': '12.06.2021',
#  'Group stage: Matchday 1_goals': 3,
# ...

# %%
country
# Out:
# 'England'

# %%
list(match_db.find({}))
# Out:
# [{'_id': ObjectId('628bcdac6a569e31fb7d1f62'),
#   'stage': 'Final',
#   'date': '11.07.2021',
#   'pens': 'True',
#   'pens_home_score': '3',
#   'pens_away_score': '2',
#   'team_name_home': 'Italy',
#   'team_name_away': 'England',
#   'team_home_score': 'True',
#   'team_away_score': 'True',
#   'possession_home': '66%',
#   'possession_away': '34%',
#   'total_shots_home': 19,
#   'total_shots_away': 6,
#   'shots_on_target_home': 6,
#   'shots_on_target_away': 2,
#   'duels_won_home': '53%',
#   'duels_won_away': '47%',
#   'events_list': [{'event_team': 'away',
#     'event_time': " 2' ",
#     'event_type': 'Goal',
#     'action_player_1': ' Luke Shaw ',
#     'action_player_2': ' Kieran Trippier '},
#    {'event_team': 'home',
#     'event_time': " 47' ",
#     'event_type': 'Yellow card',
#     'action_player_1': ' Nicolo Barella '},
#    {'event_team': 'home',
#     'event_time': " 54' ",
#     'event_type': 'Substitution',
#     'action_player_1': ' Bryan Cristante ',
# ...
